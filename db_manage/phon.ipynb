# %%
import pandas as pd
import numpy as np
import pickle 
import os

# %%
# Step 1: Open the file in read-binary mode
with open('data.pkl', 'rb') as file:
    # Step 2: Load the data from the file
    data = pickle.load(file)

# Now, `data` contains the deserialized Python object
print(data)
# Out:
# 0        JAN JAGRAN TIMES
# 1        JAGRAN CITY PLUS
# 2         SAMPURNA JAGRAN
# 3           DAINIK JAGRAN
# 4           VISHWA JAGRAN
#                ...
# 21394        KAIWART AWAZ
# 21395     SARBAHARAR AWAZ
# 21396      SHRAMIKER AWAZ
# 21397          SOBAR AWAZ
# 21398        AWAZ AAP TAK
# Name: Title Name, Length: 10790, dtype: object

# %%
data = data.str.lower()
print(data)
# Out:
# 0        jan jagran times
# 1        jagran city plus
# 2         sampurna jagran
# 3           dainik jagran
# 4           vishwa jagran
#                ...
# 21394        kaiwart awaz
# 21395     sarbaharar awaz
# 21396      shramiker awaz
# 21397          sobar awaz
# 21398        awaz aap tak
# Name: Title Name, Length: 10790, dtype: object

# %%
data = pd.DataFrame(data)
data = data.drop_duplicates().dropna()

# %%
# Rename column
from metaphone import doublemetaphone

data.rename(columns={'Title Name': 'title'}, inplace=True)
data['metaphoneA'], data['metaphoneB'] = zip(*data['title'].apply(doublemetaphone))

# %%
data
# Out:
#                   title metaphoneA metaphoneB
# 0      jan jagran times  JNJKRNTMS  ANJKRNTMS
# 1      jagran city plus  JKRNSTPLS  AKRNSTPLS
# 2       sampurna jagran  SMPRNJKRN
# 3         dainik jagran    TNKJKRN
# 4         vishwa jagran     FXJKRN
# ...                 ...        ...        ...
# 21394      kaiwart awaz       KRTS      KRTTS
# 21395   sarbaharar awaz    SRPHRRS   SRPHRRTS
# 21396    shramiker awaz     XRMKRS    XRMKRTS
# 21397        sobar awaz       SPRS      SPRTS
# 21398      awaz aap tak      ASPTK     ATSPTK
#
# [10790 rows x 3 columns]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document  # Import Document class
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)



# Convert the DataFrame to Documents with page content as metaphoneA and metaphoneB
documents = [
    Document(
        page_content=f"{row['metaphoneA']} {row['metaphoneB']}",  # Concatenate metaphoneA and metaphoneB
        metadata={'title': row['title']}
    )
    for _, row in data.iterrows()
]

# Print a sample of the documents
print(documents)
# Out:
# [Document(metadata={'title': 'jan jagran times'}, page_content='JNJKRNTMS ANJKRNTMS'), Document(metadata={'title': 'jagran city plus'}, page_content='JKRNSTPLS AKRNSTPLS'), Document(metadata={'title': 'sampurna jagran'}, page_content='SMPRNJKRN '), Document(metadata={'title': 'dainik jagran'}, page_content='TNKJKRN '), Document(metadata={'title': 'vishwa jagran'}, page_content='FXJKRN '), Document(metadata={'title': 'kishan jagran'}, page_content='KXNJKRN '), Document(metadata={'title': 'dev jagran news'}, page_content='TFJKRNNS '), Document(metadata={'title': 'dainik jagran rashtriya sanskaran'}, page_content='TNKJKRNRXTRSNSKRN '), Document(metadata={'title': 'jan jagran'}, page_content='JNJKRN ANJKRN'), Document(metadata={'title': 'vidya jagran'}, page_content='FTJKRN '), Document(metadata={'title': 'janhit jagran'}, page_content='JNTJKRN ANTJKRN'), Document(metadata={'title': 'uttrakhand jagran'}, page_content='ATRKNTJKRN '), Document(metadata={'title': 'jagran uday'}, page_content='JKRNT AKRNT'), Document(metadata={'title': 'sahakar jagran'}, page_content='SHKRJKRN '), Document(metadata={'title': 'krishi jagran'}, page_content='KRXJKRN '), Document(metadata={'title': 'm.a.c. krishi jagran'}, page_content='MMKKKRXJKRN '), Document(metadata={'title': 'jagran sakhi'}, page_content='JKRNSK AKRNSK'), Document(metadata={'title': 'jat jagran'}, page_content='JTJKRN ATJKRN'), Document(metadata={'title': 'bharat jagran'}, page_content='PRTJKRN '), Document(metadata={'title': 'gurjar jagran'}, page_content='KRJRJKRN '), Document(metadata={'title': 'upbhoktha jagran'}, page_content='APK0JKRN APKTJKRN'), Document(metadata={'title': 'jagran josh plus'}, page_content='JKRNJXPLS AKRNJXPLS'), Document(metadata={'title': 'jan jagran aandolan'}, page_content='JNJKRNNTLN ANJKRNNTLN'), Document(metadata={'title': 'kalash jagran'}, page_content='KLXJKRN '), Document(metadata={'title': 'shramik jagran'}, page_content='XRMKJKRN '), Document(metadata={'title': 'jharkhand jagran'}, page_content='JRKNTJKRN ARKNTJKRN'), Document(metadata={'title': 'jagran mantra'}, page_content='JKRNMNTR AKRNMNTR'), Document(metadata={'title': 'samajwadi jagran'}, page_content='SMJTJKRN '), Document(metadata={'title': 'vyavsai jagran'}, page_content='FFSJKRN '), Document(metadata={'title': 'mahajagran'}, page_content='MHJKRN MHHKRN'), Document(metadata={'title': 'bahujan jagran'}, page_content='PHJNJKRN PHHNJKRN'), Document(metadata={'title': 'jagran times'}, page_content='JKRNTMS AKRNTMS'), Document(metadata={'title': 'jagran junction'}, page_content='JKRNJNKXN AKRNJNKXN'), Document(metadata={'title': 'pravasi jagran'}, page_content='PRFSJKRN '), Document(metadata={'title': 'sewak jagran'}, page_content='SKJKRN '), Document(metadata={'title': 'nandigiram jagran'}, page_content='NNTJRMJKRN NNTKRMJKRN'), Document(metadata={'title': 'prakhar jagran'}, page_content='PRKRJKRN '), Document(metadata={'title': 'yug prabhat jagran'}, page_content='AKPRPTJKRN '), Document(metadata={'title': 'jan jan jagran'}, page_content='JNJNJKRN ANJNJKRN'), Document(metadata={'title': 'jagran law review'}, page_content='JKRNLRF AKRNLRFF'), Document(metadata={'title': 'patrakar jagran'}, page_content='PTRKRJKRN '), Document(metadata={'title': 'manav jagran'}, page_content='MNFJKRN '), Document(metadata={'title': 'krisak jagran'}, page_content='KRSKJKRN '), Document(metadata={'title': 'krishi jagran saptahik'}, page_content='KRXJKRNSPTHK '), Document(metadata={'title': 'vande jagran'}, page_content='FNTJKRN '), Document(metadata={'title': 'kaurav jagran'}, page_content='KRFJKRN '), Document(metadata={'title': 'shosit jagran'}, page_content='XSTJKRN '), Document(metadata={'title': 'balmik jagran'}, page_content='PLMKJKRN '), Document(metadata={'title': 'pradesh jagran'}, page_content='PRTXJKRN '), Document(metadata={'title': 'aatm jagran'}, page_content='ATMJKRN '), Document(metadata={'title': 'khatik jagran'}, page_content='KTKJKRN '), Document(metadata={'title': 'goswami jagran'}, page_con ...

# %%
split_docs = text_splitter.split_documents(documents)

# %%
print(split_docs)
# Out:
# [Document(metadata={'title': 'jan jagran times'}, page_content='JNJKRNTMS ANJKRNTMS'), Document(metadata={'title': 'jagran city plus'}, page_content='JKRNSTPLS AKRNSTPLS'), Document(metadata={'title': 'sampurna jagran'}, page_content='SMPRNJKRN'), Document(metadata={'title': 'dainik jagran'}, page_content='TNKJKRN'), Document(metadata={'title': 'vishwa jagran'}, page_content='FXJKRN'), Document(metadata={'title': 'kishan jagran'}, page_content='KXNJKRN'), Document(metadata={'title': 'dev jagran news'}, page_content='TFJKRNNS'), Document(metadata={'title': 'dainik jagran rashtriya sanskaran'}, page_content='TNKJKRNRXTRSNSKRN'), Document(metadata={'title': 'jan jagran'}, page_content='JNJKRN ANJKRN'), Document(metadata={'title': 'vidya jagran'}, page_content='FTJKRN'), Document(metadata={'title': 'janhit jagran'}, page_content='JNTJKRN ANTJKRN'), Document(metadata={'title': 'uttrakhand jagran'}, page_content='ATRKNTJKRN'), Document(metadata={'title': 'jagran uday'}, page_content='JKRNT AKRNT'), Document(metadata={'title': 'sahakar jagran'}, page_content='SHKRJKRN'), Document(metadata={'title': 'krishi jagran'}, page_content='KRXJKRN'), Document(metadata={'title': 'm.a.c. krishi jagran'}, page_content='MMKKKRXJKRN'), Document(metadata={'title': 'jagran sakhi'}, page_content='JKRNSK AKRNSK'), Document(metadata={'title': 'jat jagran'}, page_content='JTJKRN ATJKRN'), Document(metadata={'title': 'bharat jagran'}, page_content='PRTJKRN'), Document(metadata={'title': 'gurjar jagran'}, page_content='KRJRJKRN'), Document(metadata={'title': 'upbhoktha jagran'}, page_content='APK0JKRN APKTJKRN'), Document(metadata={'title': 'jagran josh plus'}, page_content='JKRNJXPLS AKRNJXPLS'), Document(metadata={'title': 'jan jagran aandolan'}, page_content='JNJKRNNTLN ANJKRNNTLN'), Document(metadata={'title': 'kalash jagran'}, page_content='KLXJKRN'), Document(metadata={'title': 'shramik jagran'}, page_content='XRMKJKRN'), Document(metadata={'title': 'jharkhand jagran'}, page_content='JRKNTJKRN ARKNTJKRN'), Document(metadata={'title': 'jagran mantra'}, page_content='JKRNMNTR AKRNMNTR'), Document(metadata={'title': 'samajwadi jagran'}, page_content='SMJTJKRN'), Document(metadata={'title': 'vyavsai jagran'}, page_content='FFSJKRN'), Document(metadata={'title': 'mahajagran'}, page_content='MHJKRN MHHKRN'), Document(metadata={'title': 'bahujan jagran'}, page_content='PHJNJKRN PHHNJKRN'), Document(metadata={'title': 'jagran times'}, page_content='JKRNTMS AKRNTMS'), Document(metadata={'title': 'jagran junction'}, page_content='JKRNJNKXN AKRNJNKXN'), Document(metadata={'title': 'pravasi jagran'}, page_content='PRFSJKRN'), Document(metadata={'title': 'sewak jagran'}, page_content='SKJKRN'), Document(metadata={'title': 'nandigiram jagran'}, page_content='NNTJRMJKRN NNTKRMJKRN'), Document(metadata={'title': 'prakhar jagran'}, page_content='PRKRJKRN'), Document(metadata={'title': 'yug prabhat jagran'}, page_content='AKPRPTJKRN'), Document(metadata={'title': 'jan jan jagran'}, page_content='JNJNJKRN ANJNJKRN'), Document(metadata={'title': 'jagran law review'}, page_content='JKRNLRF AKRNLRFF'), Document(metadata={'title': 'patrakar jagran'}, page_content='PTRKRJKRN'), Document(metadata={'title': 'manav jagran'}, page_content='MNFJKRN'), Document(metadata={'title': 'krisak jagran'}, page_content='KRSKJKRN'), Document(metadata={'title': 'krishi jagran saptahik'}, page_content='KRXJKRNSPTHK'), Document(metadata={'title': 'vande jagran'}, page_content='FNTJKRN'), Document(metadata={'title': 'kaurav jagran'}, page_content='KRFJKRN'), Document(metadata={'title': 'shosit jagran'}, page_content='XSTJKRN'), Document(metadata={'title': 'balmik jagran'}, page_content='PLMKJKRN'), Document(metadata={'title': 'pradesh jagran'}, page_content='PRTXJKRN'), Document(metadata={'title': 'aatm jagran'}, page_content='ATMJKRN'), Document(metadata={'title': 'khatik jagran'}, page_content='KTKJKRN'), Document(metadata={'title': 'goswami jagran'}, page_content='KSMJKRN'), Document(metada ...

# %%
from langchain_ollama.embeddings import OllamaEmbeddings
embeddings = OllamaEmbeddings(model ="mxbai-embed-large")

# %%
from dotenv import load_dotenv
load_dotenv()
import os
api_key = os.getenv("PINECONE_API_KEY")

# %%
from pinecone import Pinecone, ServerlessSpec
index_name = "phonaticsearch"
pc = Pinecone(api_key=api_key)
index = pc.Index(index_name)

# %%
import nltk
from pinecone_text.sparse import BM25Encoder

# Download the necessary tokenizer data

# Initialize the BM25 encoder
encoder = BM25Encoder().default()

# Your data and BM25 encoding process
# Ensure the data column is converted to a list of strings
corpus = data['title'].tolist()  # Convert the column to a list

# Fit the encoder
encoder.fit(corpus)

# Save the encoded data
encoder.dump("phon.json")
# Out:
# 100%|██████████| 10790/10790 [00:00<00:00, 18949.65it/s]

# %%
encoded_docs = BM25Encoder().load("document.json")

# %%
from langchain_community.retrievers import PineconeHybridSearchRetriever
retriever = PineconeHybridSearchRetriever(index=index, sparse_encoder=encoded_docs, embeddings=embeddings)

# %%
retriever.add_texts(
    corpus
)
# Out:
# 100%|██████████| 338/338 [07:58<00:00,  1.42s/it]

# %%
retriever.invoke("Chutiya")
# Out:
# [Document(metadata={'score': 0.344147861}, page_content='pudhiya india'),
#  Document(metadata={'score': 0.312513143}, page_content='pratigya times'),
#  Document(metadata={'score': 0.307463586}, page_content='india yug'),
#  Document(metadata={'score': 0.3040573}, page_content='charaniya times')]
